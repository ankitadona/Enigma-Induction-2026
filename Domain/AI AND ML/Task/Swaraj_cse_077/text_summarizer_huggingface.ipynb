# %% [markdown]
# # Text Summarizer using Hugging Face

# %% [markdown]
# ## Step 1 — Install Libraries

# %%
# !pip install q "transformers<5" torch

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Loading Pretrained Model

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model="facebook/bart-large-cnn",device=0)

print("Model loaded successfully!")

# %% [markdown]
# ### Input Original Text

# %%
text = input("Enter your text :\n")

print("Original Text:")
print(text)
# Out:
# Enter your text :
# Artificial Intelligence (AI) is rapidly transforming numerous industries by enabling machines to perform tasks that traditionally required human intelligence. In healthcare, AI-powered systems are being used to diagnose diseases, analyze medical images, and assist in drug discovery, leading to faster and more accurate outcomes. In the finance sector, AI algorithms detect fraudulent transactions in real time and help investment firms make data-driven decisions. The field of robotics has also benefited greatly, with intelligent robots now capable of operating in complex environments such as warehouses, construction sites, and even outer space. Furthermore, AI-driven automation is reshaping manufacturing, logistics, and customer service, reducing costs and improving efficiency. Despite these advances, AI raises important ethical questions around job displacement, data privacy, and algorithmic bias, prompting governments and organizations worldwide to develop regulatory frameworks to ensure responsible AI development.
# Original Text:
# Artificial Intelligence (AI) is rapidly transforming numerous industries by enabling machines to perform tasks that traditionally required human intelligence. In healthcare, AI-powered systems are being used to diagnose diseases, analyze medical images, and assist in drug discovery, leading to faster and more accurate outcomes. In the finance sector, AI algorithms detect fraudulent transactions in real time and help investment firms make data-driven decisions. The field of robotics has also benefited greatly, with intelligent robots now capable of operating in complex environments such as warehouses, construction sites, and even outer space. Furthermore, AI-driven automation is reshaping manufacturing, logistics, and customer service, reducing costs and improving efficiency. Despite these advances, AI raises important ethical questions around job displacement, data privacy, and algorithmic bias, prompting governments and organizations worldwide to develop regulatory frameworks to ensure responsible AI development.

# %% [markdown]
# ### Output of Summary

# %%
summary = summarizer(text, max_length=50, min_length=20, do_sample=False)

print("Summary:")
print(summary[0]['summary_text'])
# Out:
# Summary:
# Artificial Intelligence (AI) is rapidly transforming numerous industries by enabling machines to perform tasks that traditionally required human intelligence. In healthcare, AI-powered systems are being used to diagnose diseases, analyze medical images, and assist in drug discovery.
